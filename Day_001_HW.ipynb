# %% [markdown]
# # 作業1：
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# Suicide Rates Overview 1985 to 2016
# Compares socio-economic info with suicide rates by year and country
#
# ##### 1.你選的這組資料為何重要
#   探討自殺率與年齡、國家之間是否有關係，試圖尋找影響自殺率的重要因子，可做為國家施政防範之參考。
# ##### 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#   資料參考
#
#   1.United Nations Development Program. (2018). Human development index (HDI).
#
#   2.World Bank. (2018). World development indicators: GDP (current US$) by country:1985 to 2016.
#
#   3.(2017). Suicide in the Twenty-First Century [dataset].
#
#   4.World Health Organization. (2018). Suicide prevention
# #### 3.蒐集而來的資料型態為何
#   Excel/csv檔
# #### 4.這組資料想解決的問題如何評估
#   做性別/年紀/世代等的敘述統計；GDP/HDI與年紀/世代的迴歸分析等等。

# %% [markdown]
# # 作業2：
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ##### 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#   是否自由載客車隊的業績比起一般車隊更好，以載客量/載客距離/客人身分做指標討論。
#
# ##### 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#   調查每個客人的基本資料；訪問對自己載客車隊與一般車隊的看法；蒐集兩者的一月與一天的營業額做分析。
#
# ##### 3.蒐集而來的資料型態為何
#   以一台車/一個乘客做單位，製成自由載客車隊與一般車隊的兩個excel表格
#
# ##### 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#   做兩大表格各項細項的比較，並歸納出對於兩者差異的主要原因。

# %% [markdown]
# # 作業3
# ### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    mse=MSE=sum((y-yp)**2)/len(y)
    return mse
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 267.738
# The Mean absolute error is 13.164
